# %% [markdown]
# # Tech Challenge 3
# ## ETL PNAD Covid19

# %% [markdown]
# ## Introdução

# %% [markdown]
# Este projeto tem como objetivo analisar o comportamento da população brasileira durante a pandemia da COVID-19, com foco em aspectos clínicos, comportamentais e econômicos, utilizando como base os microdados da pesquisa PNAD COVID-19 disponibilizada pelo IBGE.
#
# A análise visa apoiar a tomada de decisão de um hospital, simulando um cenário em que seja necessário planejar ações estratégicas para um eventual novo surto da doença, considerando indicadores relevantes extraídos dos dados.
#
# Fonte: PNAD-COVID-19 do IBGE (https://covid19.ibge.gov.br/pnad-covid/)

# %% [markdown]
# ## Arquitetura e Pipeline de Dados (AWS)

# %% [markdown]
# 1. Ingestão dos Dados
#
# * Os dados da PNAD COVID-19 foram armazenados no Amazon S3, organizados por camadas lógicas.
#
# * O S3 atuou como Data Lake, centralizando os dados brutos e processados.
#
# 2. Processamento e Transformação (AWS Glue + Spark)
#
#   Utilização de AWS Glue (Spark) para:
#
# * Leitura dos dados brutos;
#
# * Padronização de tipos de dados;
#
# * Tratamento de valores nulos e inconsistências;
#
# * Criação da tabela fato analítica.
#
# 3. Modelagem Analítica
#
# Construção de uma tabela fato consolidada, contendo:
#
# * Respostas da pesquisa;
#
# * Informações geográficas (UF, capital, região);
#
# * Características demográficas (sexo, raça, escolaridade, idade).
#
# Criação de dimensões auxiliares para:
#
# * Perguntas e respostas;
#
# * Sexo, raça e escolaridade;
#
# * UF, capital e região.

# %% [markdown]
# ###  BIbliotecas
#
# Importação das bibliotecas necessárias para manipulação.

# %%
%idle_timeout 2880
%glue_version 5.0
%worker_type G.1X
%number_of_workers 5

import sys
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job
from pyspark.sql.functions import col, trim
from pyspark.sql.functions import col
sc = SparkContext.getOrCreate()
glueContext = GlueContext(sc)
spark = glueContext.spark_session
job = Job(glueContext)
# Out:
# You are already connected to a glueetl session e5eae2d0-41d8-4392-adf2-4a172883b65e.
#
# No change will be made to the current session that is set as glueetl. The session configuration change will apply to newly created sessions.
# Current idle_timeout is None minutes.
# idle_timeout has been set to 2880 minutes.
# You are already connected to a glueetl session e5eae2d0-41d8-4392-adf2-4a172883b65e.
#
# No change will be made to the current session that is set as glueetl. The session configuration change will apply to newly created sessions.
# Setting Glue version to: 5.0
# You are already connected to a glueetl session e5eae2d0-41d8-4392-adf2-4a172883b65e.
#
# No change will be made to the current session that is set as glueetl. The session configuration change will apply to newly created sessions.
# Previous worker type: None
# Setting new worker type to: G.1X
# You are already connected to a glueetl session e5eae2d0-41d8-4392-adf2-4a172883b65e.
#
# No change will be made to the current session that is set as glueetl. The session configuration change will apply to newly created sessions.
# Previous number of workers: None
# Setting new number of workers to: 5

# %% [markdown]
# ### Leitura dos dados (Extração)
#
# Leitura da base de dados original
#
# Os dados são carregados a partir da camada de dados brutos

# %%
spark.sql("SHOW DATABASES").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# |workspace|
# +---------+

# %%
spark.sql("SHOW TABLES IN workspace").show()
# Out:
# +---------+--------------------+-----------+
# |namespace|           tableName|isTemporary|
# +---------+--------------------+-----------+
# |workspace|_rawbase_dicionar...|      false|
# |workspace|      fato_analitica|      false|
# |workspace|  fato_analitica_geo|      false|
# |workspace|     fato_pnad_covid|      false|
# |workspace|raw_base_microdad...|      false|
# +---------+--------------------+-----------+

# %% [markdown]
# ### Tratamento inicial dos dados
#
# Tratamento inicial dos dados
# * Seleção das colunas relevantes para a análise
# * Padronização de nomes de colunas
# * Relacionamento entre as tabelas Dicionario e a base de dados para criação das fatos e dimensões

# %%
dicionario = spark.table("workspace._rawbase_dicionarios_pnad_covid")
microdados = spark.table("workspace.raw_base_microdados_pnad_covid")

# %% [markdown]
# ### Schema do Dicionário

# %%
dicionario.printSchema()
dicionario.show(10, truncate=False)
# Out:
# root
#  |-- tamanho: long (nullable = true)
#  |-- códigodavariável: string (nullable = true)
#  |-- nº: string (nullable = true)
#  |-- descrição: string (nullable = true)
#  |-- tipo: string (nullable = true)
#  |-- codigo auxiliar quesito: string (nullable = true)
#  |-- descrição quesito: string (nullable = true)
#
# +-------+----------------+---------+--------------------+---------+-----------------------+-----------------+
# |tamanho|códigodavariável|nº       |descrição           |tipo     |codigo auxiliar quesito|descrição quesito|
# +-------+----------------+---------+--------------------+---------+-----------------------+-----------------+
# |null   |"Código         |null     |null                |null     |null                   |null             |
# |null   |null            |null     |null                |null     |null                   |null             |
# |null   |nº              |Descrição|Tipo                |Descrição|Codigo Auxiliar Quesito|Descrição Quesito|
# |null   |                |         |                    |         |                       |                 |
# |4      |Ano             |         |Ano de referência   |         |                       |Ano              |
# |2      |UF              |         |Unidade da Federação|11       |Rondônia               |UF               |
# |null   |                |         |                    |12       |Acre                   |UF               |
# |null   |                |         |                    |13       |Amazonas               |UF               |
# |null   |                |         |                    |14       |Roraima                |UF               |
# |null   |                |         |                    |15       |Pará                   |UF               |
# +-------+----------------+---------+--------------------+---------+-----------------------+-----------------+
# only showing top 10 rows

# %% [markdown]
# ## Criação das Fatos e Dimensões

# %% [markdown]
# ###  Dim Pergunta
#
# A Dim pergunta traz o código da pergunta e a descrição da pergunta.

# %%
dim_pergunta = (
    dicionario
    .select(
        col("códigodavariável").alias("cod_pergunta"),
        col("descrição").alias("descricao_pergunta")
    )
    .where(col("códigodavariável").isNotNull())
    .distinct()
)

# %%
dim_pergunta.printSchema()
dim_pergunta.show(10, truncate=False)
# Out:
# root
#  |-- cod_pergunta: string (nullable = true)
#  |-- descricao_pergunta: string (nullable = true)
#
# +------------+----------------------------------------------------------------------------------------+
# |cod_pergunta|descricao_pergunta                                                                      |
# +------------+----------------------------------------------------------------------------------------+
# |C009        |Quantas horas, na semana passada, de fato trabalhou?                                    |
# |D0023       |Somatório dos valores recebidos                                                         |
# |D0031       |Rendimentos de Programa Bolsa Família                                                   |
# |D0061       |Seguro desemprego                                                                       |
# |E0023       |Este empréstimo foi adquirido com empregados ou patrão                                  |
# |F0022       |Número da faixa do aluguel pago                                                         |
# |F002A4      |No seu domicílio há os seguintes itens básicos de limpeza e proteção: luvas descartáveis|
# |D0063       |Somatório dos valores recebidos                                                         |
# |E0022       |Este empréstimo foi adquirido com parente ou amigo                                      |
# |F001        |Este domicílio é:                                                                       |
# +------------+----------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ###  Dim Resposta
#
# A Dim Resposta traz o código da pergunta, o código da resposta e a descrição da resposta.

# %%
dim_resposta = (
    dicionario
    .withColumnRenamed("descrição quesito", "cod_pergunta")
    .withColumnRenamed("tipo", "cod_resposta")
    .withColumnRenamed("codigo auxiliar quesito", "descricao_resposta")
    .select("cod_pergunta", "cod_resposta", "descricao_resposta")
    .where(col("cod_pergunta").isNotNull())
    .where(trim(col("cod_pergunta")) != "")
    .distinct()
)

# %%
dim_resposta.printSchema()
dim_resposta.show(10, truncate=False)
# Out:
# root
#  |-- cod_pergunta: string (nullable = true)
#  |-- cod_resposta: string (nullable = true)
#  |-- descricao_resposta: string (nullable = true)
#
# +------------+------------+------------------------------------+
# |cod_pergunta|cod_resposta|descricao_resposta                  |
# +------------+------------+------------------------------------+
# |C0052       |            |Não aplicável                       |
# |C0053       |            |Não aplicável                       |
# |C007A       |            |Não aplicável                       |
# |C007C       |03          |Auxiliar de escritório, escriturário|
# |C007C       |07          |Balconista, vendedor de loja        |
# |C007D       |15          |Atividades imobiliárias             |
# |C007D       |19          |Educação                            |
# |C009A       |2           |Não                                 |
# |C010        |1           |Indica se o quesito foi respondido  |
# |C01022      |            |Não aplicável                       |
# +------------+------------+------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ### Dim_UF
#
# A Dim UF traz o código UF e qual estado representa

# %%
dim_uf = (
    dim_resposta
    .filter(col("cod_pergunta") == "UF")
    .select(
        col("cod_resposta").cast("int").alias("uf"),
        col("descricao_resposta").alias("nome_uf")
    )
)

# %%
dim_uf.printSchema()
dim_uf.show(10, truncate=False)
# Out:
# root
#  |-- uf: integer (nullable = true)
#  |-- nome_uf: string (nullable = true)
#
# +---+-------------------+
# |uf |nome_uf            |
# +---+-------------------+
# |14 |Roraima            |
# |24 |Rio Grande do Norte|
# |33 |Rio de Janeiro     |
# |41 |Paraná             |
# |43 |Rio Grande do Sul  |
# |51 |Mato Grosso        |
# |27 |Alagoas            |
# |50 |Mato Grosso do Sul |
# |52 |Goiás              |
# |21 |Maranhão           |
# +---+-------------------+
# only showing top 10 rows

# %% [markdown]
# ### Dim Capital
#
# A Dim Capital traz o código da capital e o nome da capital relacionada

# %%
dim_capital = (
    dim_resposta
    .filter(col("cod_pergunta") == "CAPITAL")
    .select(
        col("cod_resposta").cast("int").alias("capital"),
        col("descricao_resposta").alias("descricao_capital")
    )
)

# %%
dim_capital.printSchema()
dim_capital.show(10, truncate=False)
# Out:
# root
#  |-- capital: integer (nullable = true)
#  |-- descricao_capital: string (nullable = true)
#
# +-------+--------------------------------+
# |capital|descricao_capital               |
# +-------+--------------------------------+
# |33     |Município de Rio de Janeiro (RJ)|
# |12     |Município de Rio Branco (AC)    |
# |22     |Município de Teresina (PI)      |
# |42     |Município de Florianópolis (SC) |
# |50     |Município de Campo Grande (MS)  |
# |11     |Município de Porto Velho (RO)   |
# |13     |Município de Manaus (AM)        |
# |17     |Município de Palmas (TO)        |
# |23     |Município de Fortaleza (CE)     |
# |15     |Município de Belém (PA)         |
# +-------+--------------------------------+
# only showing top 10 rows

# %% [markdown]
# ### Dim_Sexo
#
# A Dim Sexo traz o código sexo e qual valore ela representa (Mulher ou Homem)

# %%
dim_sexo = (
    dim_resposta
    .filter(col("cod_pergunta") == "A003")
    .select(
        col("cod_resposta").alias("cod_sexo"),
        col("descricao_resposta").alias("descricao_sexo")
    )
    .where(col("cod_sexo").isNotNull())
    .distinct()
)

# %%
dim_sexo.printSchema()
dim_sexo.show(10, truncate=False)
# Out:
# root
#  |-- cod_sexo: string (nullable = true)
#  |-- descricao_sexo: string (nullable = true)
#
# +--------+--------------+
# |cod_sexo|descricao_sexo|
# +--------+--------------+
# |2       |Mulher        |
# |1       |Homem         |
# +--------+--------------+

# %% [markdown]
# ### Dim_Raca
#
# A Dim Raça traz o código da raça e qual raça ela representa

# %%
dim_raca = (
    dim_resposta
    .filter(col("cod_pergunta") == "A004")
    .select(
        col("cod_resposta").alias("cod_raca"),
        col("descricao_resposta").alias("descricao_raca")
    )
    .where(col("cod_raca").isNotNull())
    .distinct()
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4015217006.py in <cell line: 0>()
#       1 dim_raca = (
# ----> 2     dim_resposta
#       3     .filter(col("cod_pergunta") == "A004")
#       4     .select(
#       5         col("cod_resposta").alias("cod_raca"),
#
# NameError: name 'dim_resposta' is not defined

# %%
dim_raca.printSchema()
dim_raca.show(10, truncate=False)
# Out:
# root
#  |-- cod_raca: string (nullable = true)
#  |-- descricao_raca: string (nullable = true)
#
# +--------+--------------+
# |cod_raca|descricao_raca|
# +--------+--------------+
# |1       |Branca        |
# |4       |Parda         |
# |5       |Indígena      |
# |9       |Ignorado      |
# |3       |Amarela       |
# |2       |Preta         |
# +--------+--------------+

# %% [markdown]
# ### Criar Dim_escolaridade
#
# A Dim escolaridade traz o código da escolaridade e a descrição que ele representa

# %%
dim_escolaridade = (
    dim_resposta
    .filter(col("cod_pergunta") == "A005")
    .select(
        col("cod_resposta").alias("cod_escolaridade"),
        col("descricao_resposta").alias("descricao_escolaridade")
    )
    .where(col("cod_escolaridade").isNotNull())
    .distinct()
)

# %%
dim_escolaridade.printSchema()
dim_escolaridade.show(10, truncate=False)
# Out:
# root
#  |-- cod_escolaridade: string (nullable = true)
#  |-- descricao_escolaridade: string (nullable = true)
#
# +----------------+------------------------------------+
# |cod_escolaridade|descricao_escolaridade              |
# +----------------+------------------------------------+
# |3               |Fundamental completa                |
# |1               |Sem instrução                       |
# |7               |Superior completo                   |
# |2               |Fundamental incompleto              |
# |4               |Médio incompleto                    |
# |8               |Pós-graduação, mestrado ou doutorado|
# |5               |Médio completo                      |
# |6               |Superior incompleto                 |
# +----------------+------------------------------------+

# %% [markdown]
# ## Criar Fato

# %% [markdown]
# Identificação das perguntas que serão usadas.
#
# Conforme proposta do projeto, foram selecionadas 20 perguntas

# %%
perguntas = [
"B0011",
"B0012",
"B0013",
"B0014",
"B0015",
"B0016",
"B0017",
"B0019",
"B0037",
"B002",
"B0032",
"B0033",
"B0034",
"B005",
"C001",
"C002",
"C003",
"C005",
"C006",
"E001"
]

# %% [markdown]
# Criação da fato principal contendo todos os códigos necessários para a futura criação das tabelas de análise

# %%
expr = ", ".join([f"'{p}', {p}" for p in perguntas])

fato_long = microdados.selectExpr(
    "ano",
    "uf",
    "capital",
    f"stack({len(perguntas)}, {expr}) as (cod_pergunta, cod_resposta)"
)

# %%
expr = ", ".join([f"'{p}', {p}" for p in perguntas])

fato_base = microdados.selectExpr(
    "ano",
    "v1013 as mes",
    "uf",
    "capital",

    # características da população
    "A002 as idade",
    "A003 as sexo",
    "A004 as raca",
    "A005 as escolaridade",

    # perguntas (formato long)
    f"stack({len(perguntas)}, {expr}) as (cod_pergunta, cod_resposta)"
)

# %% [markdown]
# Tratativa para elimitar respostas nulas

# %%
fato_base.where(col("cod_resposta").isNotNull()).show(20, truncate=False)
# Out:
# +----+---+---+-------+-----+----+----+------------+------------+------------+
# |ano |mes|uf |capital|idade|sexo|raca|escolaridade|cod_pergunta|cod_resposta|
# +----+---+---+-------+-----+----+----+------------+------------+------------+
# |2020|9  |11 |11     |36   |1   |4   |5           |B0011       |2           |
# |2020|9  |11 |11     |36   |1   |4   |5           |B0012       |2           |
# |2020|9  |11 |11     |36   |1   |4   |5           |B0013       |2           |
# |2020|9  |11 |11     |36   |1   |4   |5           |B0014       |2           |
# |2020|9  |11 |11     |36   |1   |4   |5           |B0015       |2           |
# |2020|9  |11 |11     |36   |1   |4   |5           |B0016       |2           |
# |2020|9  |11 |11     |36   |1   |4   |5           |B0017       |2           |
# |2020|9  |11 |11     |36   |1   |4   |5           |B0019       |2           |
# |2020|9  |11 |11     |36   |1   |4   |5           |C001        |1           |
# |2020|9  |11 |11     |36   |1   |4   |5           |C006        |2           |
# |2020|9  |11 |11     |36   |1   |4   |5           |E001        |3           |
# |2020|9  |11 |11     |30   |2   |4   |7           |B0011       |2           |
# |2020|9  |11 |11     |30   |2   |4   |7           |B0012       |2           |
# |2020|9  |11 |11     |30   |2   |4   |7           |B0013       |2           |
# |2020|9  |11 |11     |30   |2   |4   |7           |B0014       |2           |
# |2020|9  |11 |11     |30   |2   |4   |7           |B0015       |2           |
# |2020|9  |11 |11     |30   |2   |4   |7           |B0016       |2           |
# |2020|9  |11 |11     |30   |2   |4   |7           |B0017       |2           |
# |2020|9  |11 |11     |30   |2   |4   |7           |B0019       |2           |
# |2020|9  |11 |11     |30   |2   |4   |7           |C001        |1           |
# +----+---+---+-------+-----+----+----+------------+------------+------------+
# only showing top 20 rows

# %%
fato_base = fato_base.filter(col("cod_resposta").isNotNull())

# %% [markdown]
# Relacionamento das tabelas fato e dimensões (Pergunta e Resposta)

# %%
fato_analitica = (
    fato_base
    .join(dim_pergunta, "cod_pergunta", "left")
    .join(dim_resposta, ["cod_pergunta", "cod_resposta"], "left")
)

# %%
fato_analitica.where(col("cod_resposta").isNotNull()).show(20, truncate=False)
# Out:
# +------------+------------+----+---+---+-------+-----+----+----+------------+----------------------------------------------------------------------------------+------------------+
# |cod_pergunta|cod_resposta|ano |mes|uf |capital|idade|sexo|raca|escolaridade|descricao_pergunta                                                                |descricao_resposta|
# +------------+------------+----+---+---+-------+-----+----+----+------------+----------------------------------------------------------------------------------+------------------+
# |B0015       |2           |2020|9  |33 |33     |61   |2   |1   |6           |Na semana passada teve dor de cabeça?                                             |Não               |
# |B0019       |2           |2020|9  |33 |33     |61   |2   |1   |6           |Na semana passada teve fadiga?                                                    |Não               |
# |B0015       |2           |2020|9  |33 |33     |71   |1   |1   |7           |Na semana passada teve dor de cabeça?                                             |Não               |
# |B0019       |2           |2020|9  |33 |33     |71   |1   |1   |7           |Na semana passada teve fadiga?                                                    |Não               |
# |B0017       |2           |2020|9  |33 |33     |61   |2   |1   |6           |Na semana passada teve náusea?                                                    |Não               |
# |B0017       |2           |2020|9  |33 |33     |71   |1   |1   |7           |Na semana passada teve náusea?                                                    |Não               |
# |B0012       |2           |2020|9  |33 |33     |61   |2   |1   |6           |Na semana passada teve tosse?                                                     |Não               |
# |C001        |2           |2020|9  |33 |33     |61   |2   |1   |6           |Na semana passada, por pelo menos uma hora, trabalhou ou fez algum bico?          |Não               |
# |E001        |3           |2020|9  |33 |33     |61   |2   |1   |6           |Durante o período da pandemia alguém deste domicílio solicitou algum empréstimo?  |Não solicitou     |
# |B0012       |2           |2020|9  |33 |33     |71   |1   |1   |7           |Na semana passada teve tosse?                                                     |Não               |
# |C001        |1           |2020|9  |33 |33     |71   |1   |1   |7           |Na semana passada, por pelo menos uma hora, trabalhou ou fez algum bico?          |Sim               |
# |B0013       |2           |2020|9  |33 |33     |61   |2   |1   |6           |Na semana passada teve dor de garganta?                                           |Não               |
# |B0014       |2           |2020|9  |33 |33     |61   |2   |1   |6           |Na semana passada teve dificuldade para respirar?                                 |Não               |
# |B0013       |2           |2020|9  |33 |33     |71   |1   |1   |7           |Na semana passada teve dor de garganta?                                           |Não               |
# |B0014       |2           |2020|9  |33 |33     |71   |1   |1   |7           |Na semana passada teve dificuldade para respirar?                                 |Não               |
# |B0011       |2           |2020|9  |33 |33     |61   |2   |1   |6           |Na semana passada teve febre?                                                     |Não               |
# |C002        |2           |2020|9  |33 |33     |61   |2   |1   |6           |Na semana passada, estava temporariamente afastado de algum trabalho?             |Não               |
# |B0011       |2           |2020|9  |33 |33     |71   |1   |1   |7           |Na semana passada teve febre?                                                     |Não               |
# |C006        |2           |2020|9  |33 |33     |71   |1   |1   |7           |Tem mais de um trabalho                                                           |Não               |
# |B0016       |2           |2020|9  |33 |33     |61   |2   |1   |6           |Na semana passada teve dor no peito?                                              |Não               |
# +------------+------------+----+---+---+-------+-----+----+----+------------+----------------------------------------------------------------------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# Relacionamento entre as tabelas fato e dimensões (UF e Capital)

# %%
fato_analitica_geo = (
    fato_analitica
    .join(dim_uf, "uf", "left")
    .join(dim_capital, "capital", "left")
)

# %%
fato_analitica_geo.where(col("cod_resposta").isNotNull()).show(20, truncate=False)
# Out:
# +-------+---+------------+------------+----+---+-----+----+----+------------+----------------------------------------------------------------------------------+------------------+--------------+--------------------------------+
# |capital|uf |cod_pergunta|cod_resposta|ano |mes|idade|sexo|raca|escolaridade|descricao_pergunta                                                                |descricao_resposta|nome_uf       |descricao_capital               |
# +-------+---+------------+------------+----+---+-----+----+----+------------+----------------------------------------------------------------------------------+------------------+--------------+--------------------------------+
# |33     |33 |B0015       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve dor de cabeça?                                             |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0019       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve fadiga?                                                    |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0015       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve dor de cabeça?                                             |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0019       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve fadiga?                                                    |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0017       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve náusea?                                                    |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0017       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve náusea?                                                    |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0012       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve tosse?                                                     |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |C001        |2           |2020|9  |61   |2   |1   |6           |Na semana passada, por pelo menos uma hora, trabalhou ou fez algum bico?          |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |E001        |3           |2020|9  |61   |2   |1   |6           |Durante o período da pandemia alguém deste domicílio solicitou algum empréstimo?  |Não solicitou     |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0012       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve tosse?                                                     |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |C001        |1           |2020|9  |71   |1   |1   |7           |Na semana passada, por pelo menos uma hora, trabalhou ou fez algum bico?          |Sim               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0013       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve dor de garganta?                                           |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0014       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve dificuldade para respirar?                                 |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0013       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve dor de garganta?                                           |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0014       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve dificuldade para respirar?                                 |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0011       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve febre?                                                     |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |C002        |2           |2020|9  |61   |2   |1   |6           |Na semana passada, estava temporariamente afastado de algum trabalho?             |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0011       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve febre?                                                     |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |C006        |2           |2020|9  |71   |1   |1   |7           |Tem mais de um trabalho                                                           |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# |33     |33 |B0016       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve dor no peito?                                              |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|
# +-------+---+------------+------------+----+---+-----+----+----+------------+----------------------------------------------------------------------------------+------------------+--------------+--------------------------------+
# only showing top 20 rows

# %% [markdown]
# ### Inclusão das caracteristicas

# %%
fato_analitica_final = (
    fato_analitica_geo
    # características da população
    .join(dim_sexo, fato_analitica_geo.sexo == dim_sexo.cod_sexo, "left")
    .join(dim_raca, fato_analitica_geo.raca == dim_raca.cod_raca, "left")
    .join(
        dim_escolaridade,
        fato_analitica_geo.escolaridade == dim_escolaridade.cod_escolaridade,
        "left"
    )
)

# %% [markdown]
# ### Fato final

# %%
fato_analitica_final.where(col("cod_resposta").isNotNull()).show(20, truncate=False)
# Out:
# +-------+---+------------+------------+----+---+-----+----+----+------------+----------------------------------------------------------------------------------+------------------+--------------+--------------------------------+--------+--------------+--------+--------------+----------------+----------------------+
# |capital|uf |cod_pergunta|cod_resposta|ano |mes|idade|sexo|raca|escolaridade|descricao_pergunta                                                                |descricao_resposta|nome_uf       |descricao_capital               |cod_sexo|descricao_sexo|cod_raca|descricao_raca|cod_escolaridade|descricao_escolaridade|
# +-------+---+------------+------------+----+---+-----+----+----+------------+----------------------------------------------------------------------------------+------------------+--------------+--------------------------------+--------+--------------+--------+--------------+----------------+----------------------+
# |33     |33 |B0015       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve dor de cabeça?                                             |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|2       |Mulher        |1       |Branca        |6               |Superior incompleto   |
# |33     |33 |B0019       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve fadiga?                                                    |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|2       |Mulher        |1       |Branca        |6               |Superior incompleto   |
# |33     |33 |B0015       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve dor de cabeça?                                             |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|1       |Homem         |1       |Branca        |7               |Superior completo     |
# |33     |33 |B0019       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve fadiga?                                                    |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|1       |Homem         |1       |Branca        |7               |Superior completo     |
# |33     |33 |B0017       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve náusea?                                                    |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|2       |Mulher        |1       |Branca        |6               |Superior incompleto   |
# |33     |33 |B0017       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve náusea?                                                    |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|1       |Homem         |1       |Branca        |7               |Superior completo     |
# |33     |33 |B0012       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve tosse?                                                     |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|2       |Mulher        |1       |Branca        |6               |Superior incompleto   |
# |33     |33 |C001        |2           |2020|9  |61   |2   |1   |6           |Na semana passada, por pelo menos uma hora, trabalhou ou fez algum bico?          |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|2       |Mulher        |1       |Branca        |6               |Superior incompleto   |
# |33     |33 |E001        |3           |2020|9  |61   |2   |1   |6           |Durante o período da pandemia alguém deste domicílio solicitou algum empréstimo?  |Não solicitou     |Rio de Janeiro|Município de Rio de Janeiro (RJ)|2       |Mulher        |1       |Branca        |6               |Superior incompleto   |
# |33     |33 |B0012       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve tosse?                                                     |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|1       |Homem         |1       |Branca        |7               |Superior completo     |
# |33     |33 |C001        |1           |2020|9  |71   |1   |1   |7           |Na semana passada, por pelo menos uma hora, trabalhou ou fez algum bico?          |Sim               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|1       |Homem         |1       |Branca        |7               |Superior completo     |
# |33     |33 |B0013       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve dor de garganta?                                           |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|2       |Mulher        |1       |Branca        |6               |Superior incompleto   |
# |33     |33 |B0014       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve dificuldade para respirar?                                 |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|2       |Mulher        |1       |Branca        |6               |Superior incompleto   |
# |33     |33 |B0013       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve dor de garganta?                                           |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|1       |Homem         |1       |Branca        |7               |Superior completo     |
# |33     |33 |B0014       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve dificuldade para respirar?                                 |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|1       |Homem         |1       |Branca        |7               |Superior completo     |
# |33     |33 |B0011       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve febre?                                                     |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|2       |Mulher        |1       |Branca        |6               |Superior incompleto   |
# |33     |33 |C002        |2           |2020|9  |61   |2   |1   |6           |Na semana passada, estava temporariamente afastado de algum trabalho?             |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|2       |Mulher        |1       |Branca        |6               |Superior incompleto   |
# |33     |33 |B0011       |2           |2020|9  |71   |1   |1   |7           |Na semana passada teve febre?                                                     |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|1       |Homem         |1       |Branca        |7               |Superior completo     |
# |33     |33 |C006        |2           |2020|9  |71   |1   |1   |7           |Tem mais de um trabalho                                                           |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|1       |Homem         |1       |Branca        |7               |Superior completo     |
# |33     |33 |B0016       |2           |2020|9  |61   |2   |1   |6           |Na semana passada teve dor no peito?                                              |Não               |Rio de Janeiro|Município de Rio de Janeiro (RJ)|2       |Mulher        |1       |Branca        |6               |Superior incompleto   |
# +-------+---+------------+------------+----+---+-----+----+----+------------+----------------------------------------------------------------------------------+------------------+--------------+--------------------------------+--------+--------------+--------+--------------+----------------+----------------------+
# only showing top 20 rows

# %% [markdown]
# ## Extração da base tratada

# %% [markdown]
# Extração da 1ª versão da fato para análise de forma parcionada

# %%
(
    fato_analitica
    .write
    .mode("overwrite")
    .option("header", "true")
    .csv("s3://lab-232736165724/data-output/fato_analitica/")
)

# %% [markdown]
# ### Extração da 2ª versão

# %%
(
    fato_analitica_geo
    .write
    .mode("overwrite")
    .option("header", "true")
    .csv("s3://lab-232736165724/data-output/fato_analitica_geo/")
)

# %% [markdown]
# ### Extração da versão final

# %%
(
    fato_analitica_final
    .write
    .mode("overwrite")
    .option("header", "true")
    .csv("s3://lab-232736165724/data-output/fato_analitica_final/")
)

# %% [markdown]
# ## Conclusão
